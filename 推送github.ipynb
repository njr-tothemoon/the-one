# %%
import os
from google.colab import drive, userdata

# 1. 確保掛載雲端硬碟並進入正確目錄
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/Colab Notebooks/stock_auction_pred_project/"

# # 2. 設定區（請確認 Token 名稱是否為 'project'）
token = userdata.get('project')
username = "njr-tothemoon"
repo_name = "the-one"
repo_url = f"https://{token}@github.com/{username}/{repo_name}.git"

# 3. 基本環境設定 (只需確保 origin 正確)
# !git config --global user.email "j341111@gmail.com"
# !git config --global user.name "{username}"

# 檢查是否有 .git 資料夾，若無則初始化
if not os.path.exists('.git'):
    # !git init
    # !git checkout -b main
    # !git remote add origin {repo_url}
else:
    # 確保遠端 URL 包含最新的 Token
    # !git remote set-url origin {repo_url}

# # 4. 準備提交
# # 這裡使用 "*" 抓取所有筆記本，或使用 "." 抓取資料夾內所有變動
# !git add "競拍資料爬蟲.ipynb"

# print("\n--- 目前準備上傳的變動狀態 ---")
# !git status

# # 5. 執行提交與推送
# commit_message = "更新專題筆記本紀錄" # 這裡可以改成你想要的訊息
# !git commit -m "{commit_message}"

# # 推送 (穩定後建議不加 -f，若需要強制覆蓋則加上)
# # !git push origin main
# !git push origin main -f
# print("\n--- ✅ 更新完畢，請至 GitHub 確認 ---")


#---------------------------------------------------------------------------------------------
# 1. 抓取所有變動（包含你修改的內容或新加的檔案）
# !git add "興櫃資料爬取_歷史行情.ipynb"
# B. 同時確認「刪除」那個檔案（如果不做這步，Git 會一直報錯不讓你 pull）
# !git rm "興櫃資料爬取.ipynb"
# 2. 紀錄這次改了什麼（引號內文字可以隨便改）
# !git commit -m "first_爬取競拍資料競拍前最近一季財報"
# !git pull origin main --rebase
# 3. 推送到 GitHub
# !git push origin main
# Out:
# /content/drive/MyDrive/Colab Notebooks/stock_auction_pred_project
# [main 0199e27] first_爬取競拍資料競拍前最近一季財報
#  1 file changed, 1 insertion(+)
#  create mode 100644 "\350\210\210\346\253\203\350\263\207\346\226\231\347\210\254\345\217\226_\346\255\267\345\217\262\350\241\214\346\203\205.ipynb"
# error: cannot pull with rebase: You have unstaged changes.
# error: please commit or stash them.
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 6.45 KiB | 550.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/njr-tothemoon/the-one.git
#    efa20f8..0199e27  main -> main

# %%
# !git ls-files
# !git branch
# !git branch -a
# !git mv "興櫃資料爬取_歷史行情.ipynb" "興櫃資料爬取_歷史財報.ipynb"
# !git add .
# !git commit -m "rename notebook file"
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
